# %%
from bs4 import BeautifulSoup
import requests

#setup
base = 'https://cnn.com/'
links = []
headlines = []

#set target genre
url = 'https://www.cnn.com/us/space-science'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'lxml')
counter = 1

# %%
#scrape for links   
for link in soup.find_all('a', {"class" : "container__link container_grid-4__link"})[:40]:
    #cnn uses link format twice (for headline hyperlink and thumbnail hyperlink), so to avoid scraping same uri twice
    if "videos" not in link.get('href'):
        if not (counter % 2 == 0):
            links.append(base[:-1]+link.get('href'))
        counter += 1

counter = 1
for link in links:
    print(str(counter) + ")" + link + '\n')
    counter += 1
# Out:
# 1)https://cnn.com/2023/09/28/world/harvest-supermoon-full-moon-september-scn/index.html
#
# 2)https://cnn.com/2023/09/28/world/fairy-circles-new-sites-scn/index.html
#
# 3)https://cnn.com/2023/09/27/world/webb-europa-carbon-detection-scn/index.html
#
# 4)https://cnn.com/2023/09/27/world/new-pangolin-species-discovery-scn/index.html
#
# 5)https://cnn.com/2023/09/27/world/frank-rubio-nasa-return-space-station-scn/index.html
#
# 6)https://cnn.com/2023/09/26/world/electric-blue-tarantula-discovered-thailand-scn-scli-intl/index.html
#
# 7)https://cnn.com/2023/09/25/business/blue-origin-ceo-amazon-jeff-bezos-scn/index.html
#
# 8)https://cnn.com/2023/09/25/world/osiris-apophis-mission-scn/index.html
#
# 9)https://cnn.com/2023/09/25/world/brian-may-osiris-rex-asteroid-sample-bennu-scn-intl-scli/index.html
#
# 10)https://cnn.com/2023/09/22/world/jellyfish-brain-central-nervous-system-learning-scn/index.html
#
# 11)https://cnn.com/2023/09/09/world/nasa-osiris-rex-sample-rehearsal-scn/index.html
#
# 12)https://cnn.com/2023/09/24/world/osiris-rex-asteroid-sample-return-scn/index.html
#
# 13)https://cnn.com/2023/09/21/world/nasa-osiris-rex-asteroid-sample-return-scn/index.html
#
# 14)https://cnn.com/2023/09/24/world/astronaut-migrant-worker-hernandez-scn-cec/index.html
#
# 15)https://cnn.com/2023/09/23/world/osiris-rex-sample-science-newsletter-wt-scn/index.html
#
# 16)https://cnn.com/2023/09/20/world/archeologists-discover-ancient-child-shoe-intl-scli-scn/index.html
#
# 17)https://cnn.com/2023/09/21/world/jawless-fish-eriptychius-americanus-3d-fossil-scn/index.html

# %%
counter = 1
#scrape for headlines
for link in links[:16]:
    #setup soup
    url = link
    page = requests.get(url)
    soup = BeautifulSoup(page.content,'lxml')

    for headline in soup.find_all('h1', {"class":"headline__text inline-placeholder"}):
        headlines.append("{}".format(headline.text))

for headline in headlines:
    print(str(counter) + ")" + headline + '\n')
    counter += 1
# Out:
# 1)
#       September’s full harvest moon is the last supermoon of the year
#
#
# 2)
#       Mysterious ‘fairy circles’ identified at hundreds of sites worldwide, new study says
#
#
# 3)
#       Webb spots a building block of life on Jupiter’s moon Europa
#
#
# 4)
#       Newly discovered pangolin species could aid in fight against extinction
#
#
# 5)
#       NASA astronaut Frank Rubio returns from record-setting mission in space
#
#
# 6)
#       Electric blue tarantula species discovered in Thailand
#
#
# 7)
#       Longtime Amazon executive to take over Jeff Bezos’ rocket company
#
#
# 8)
#       Asteroid named for Egyptian god of chaos and darkness set for spacecraft flyby
#
#
# 9)
#       Queen’s Brian May helped NASA return its first asteroid sample
#
#
# 10)
#       Surprising jellyfish finding challenges what’s known about learning and memory
#
#
# 11)
#       A long-awaited sample from a near-Earth asteroid is about to land in the US
#
#
# 12)
#       A long-awaited asteroid sample has landed in the US
#
#
# 13)
#       An asteroid sample is about to land on Earth. Here’s what to expect
#
#
# 14)
#       NASA rejected him 11 times before making him an astronaut. Now his life story is a movie
#
#
# 15)
#       A 7-year journey to deliver an asteroid sample to Earth will soon end in Utah
#
#
# 16)
#       Archaeologists discover 2,000-year-old child’s shoe with laces intact

# %%
counter = 1
#scrape science links for info
for link in links[:16]:
    #setup soup
    url = link
    page = requests.get(url)
    soup = BeautifulSoup(page.content,'lxml')

    if counter<10: 
        file = open("science_040"+str(counter)+".txt",'w')
    else:
        file = open("science_04"+str(counter)+".txt",'w')
    file.write("\n**********************************************************\n")
    file.write(link + '\n')
    file.write('\n'+str(counter) +") " + headlines[counter-1])
    file.write('\n')

    #print scraped info
    for location in soup.find_all('div', {"class":"byline__names"}):
        #CNN is based in Atlanta, Georgia. All articles are published by CNN
        file.write(location.text.strip() + " Atlanta, Georgia")
    for date in soup.find_all('div', {"class" : "timestamp"}):
        file.write("\n" + date.text.strip() + '\n')
    for content in soup.find_all('p', {"class" : "paragraph"}):
        file.write(content.text.strip())
    file.close()
    counter += 1
